# %%
#ques1
import numpy as np
arr=(np.random.random((10,1))) #random array of shape(10,1)
print(np.mean(arr))
# Out:
# 0.4807586402471036

# %%
#ques2
import numpy as np
import math
arr=(np.random.random((20,1))) #random array of shape(20,1)
b=(np.std(arr))
print(b)
print(np.sqrt(b))
# Out:
# 0.32542803079198723
# 0.5704629968648162

# %%
#ques3
import numpy as np
arr=(np.random.random((10,20)))
arrr=(np.random.random((20,25)))
c=(np.matmul(arr,arrr))
print(c)
print(c.shape)
print(np.sum(c))
# Out:
# [[4.75171848 4.7393274  5.33110403 5.07740136 3.28346952 5.34919489
#   5.58001505 4.9561943  5.21335173 5.25187907 5.83260215 6.13626222
#   5.18467335 4.78298006 4.84166175 5.3287288  5.28865115 5.08540915
#   5.47060067 4.94067419 4.57844993 5.64812677 5.69365078 4.47048677
#   6.12316333]
#  [6.13643295 6.22309007 6.2610668  5.63278643 4.21148641 6.89204349
#   6.61769214 6.26085329 6.0500212  6.836622   6.4384359  6.50594932
#   6.29580192 5.49562503 6.20532763 6.2349837  6.12622581 6.64013743
#   6.5364421  6.30866025 5.33577536 6.65379582 6.21098584 5.60727558
#   7.1566451 ]
#  [3.92310758 4.21813629 4.02356483 4.47789523 3.12669347 4.61515
#   3.81572088 3.44463468 3.37195497 4.13444987 4.74250576 3.41757004
#   4.01606829 3.74299529 4.06079126 3.42487123 4.00817314 3.99491089
#   3.90515437 4.25713192 3.00207669 4.16169455 4.4198591  3.69917788
#   4.54145996]
#  [6.4526063  6.66299631 6.25270443 6.09531267 4.61263185 7.05917198
# ...

# %%
#ques4
import numpy as np
arr=np.random.random((10,1))
def f(arr):
    return 1/(1+np.exp(-arr))
result=f(arr)
print(result)
# Out:
# [[0.7123162 ]
#  [0.69501405]
#  [0.53576229]
#  [0.58454461]
#  [0.56466745]
#  [0.61297593]
#  [0.51216871]
#  [0.64557232]
#  [0.68170308]
#  [0.7076049 ]]
# **********
# [array([0.7123162]), array([0.69501405]), array([0.53576229]), array([0.58454461]), array([0.56466745]), array([0.61297593]), array([0.51216871]), array([0.64557232]), array([0.68170308]), array([0.7076049])]
