# %%
#Question 1
import pandas as pd
df=pd.DataFrame({
    'Name':['Praful Rana','Nikhil Thakur','Praful Rana','Nikhil Sharma','Shubhrant Yadav'],
    'Age':[20,21,20,20,20],
    'Mailid':['prpraful21@gmail.com','nikhilthakur031@gmail.com','ranapraful21@gmail.com','nikhil.d.hunk@gmail.com','shubhrant100@gmail.com'],
    'Phone No.':[7894561230,9832465654,8346576546,7436587998,7462559034]
})
df
# Out:
#               Name  Age                     Mailid   Phone No.
# 0      Praful Rana   20       prpraful21@gmail.com  7894561230
# 1    Nikhil Thakur   21  nikhilthakur031@gmail.com  9832465654
# 2      Praful Rana   20     ranapraful21@gmail.com  8346576546
# 3    Nikhil Sharma   20    nikhil.d.hunk@gmail.com  7436587998
# 4  Shubhrant Yadav   20     shubhrant100@gmail.com  7462559034

# %%
#Question 2

df1=pd.read_csv('https://raw.githubusercontent.com/Shreyas3108/Weather/master/weather.csv')
print(df1.head())
print('*'*20)
print(df1.head(10))
print('*'*20)
print(df1.describe())
print('*'*20)
print(df1.tail())
print('*'*20)
print(df1['Location'].describe())
# Out:
#         Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  11/1/2007  Canberra      8.0     24.3       0.0          3.4       6.3
# 1  11/2/2007  Canberra     14.0     26.9       3.6          4.4       9.7
# 2  11/3/2007  Canberra     13.7     23.4       3.6          5.8       3.3
# 3  11/4/2007  Canberra     13.3     15.5      39.8          7.2       9.1
# 4  11/5/2007  Canberra      7.6     16.1       2.8          5.6      10.6
#
#   WindGustDir  WindGustSpeed WindDir9am      ...      Humidity3pm  \
# 0          NW           30.0         SW      ...               29
# 1         ENE           39.0          E      ...               36
# 2          NW           85.0          N      ...               69
# 3          NW           54.0        WNW      ...               56
# 4         SSE           50.0        SSE      ...               49
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...
